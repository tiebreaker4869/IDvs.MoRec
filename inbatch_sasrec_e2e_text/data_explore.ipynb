# %%
import pandas as pd

# %%
result = pd.read_csv('top100_recommendations.csv')

# %%
result.head(100)
# Out:
#     User ID                                      Top 100 Items  \
# 0         0  [59074 66281 65735 57553 67810 58098 64530 743...
# 1         1  [70738 60091 73222 70243 69269 70074 58575 597...
# 2         2  [70903 67934 58005 34598 58098 73496 57413 611...
# 3         3  [59577 68298 76421 74112 66281 74709 70738 596...
# 4         4  [59689 67980 67978 76421 65367 69269 75047 590...
# ..      ...                                                ...
# 95       95  [78051 78156 77596 61116 61379 61283 59897 646...
# 96       96  [61645 62075 63649 62771 63826 67519 29168 729...
# 97       97  [70243 66281 68298 60917 61645 70015 69515 641...
# 98       98  [24786 21963 35179 53649 15688 55897 41978 176...
# 99       99  [69269 68298 70243 59002 61645 69416 70738 671...
#
#                                        Top 100 Scores
# 0   [0.06557453 0.04773502 0.04167578 0.03908418 0...
# 1   [0.10013087 0.08872008 0.0538477  0.04962774 0...
# ...

# %%
len(result)
# Out:
# 630272
